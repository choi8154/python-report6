# %% [markdown]
# ## Mini project [행맨 게임 제작]
#
# 안녕하세요.
# 수강생 여러분~! Chapter 1 ~ 6 까지의 수업은 잘 들으셨나요?
#
# 여러분의 모든 역량을 총 동원해 문제를 풀어주셨합니다.
#
#
#
# #### 과제 설명
#
# 이번 개발 주제는 '행맨' 게임이구요.
#
# 행맨 게임은 아주 유명한 단어 퀴즈 프로그램이예요
#
# 어떤 단어가 주어지면 그 단어의 길이만큼 빈 칸(밑줄) 이 주어지고
# 플레이어는 알파벳을 하나씩 얘기하면서 단어를 추측해요!
#
# 7번 틀리게 되면 게임이 끝납니다. 🥲

# %% [markdown]
# #### 예시를 들어볼께요!!
#
# 만약 E 가 단어에 포함돼있다면, 해당하는 위치에 E 를 표시해줍니다
#
# _ _ _ _ E E
# 이렇게 되겠네요.
#
# 이번에는 A를 해볼께요
# A 는 포함되지 않으므로 기회가 줄어들고 지금까지 맞힌 내용 그대로 출력합니다.
#
# _ _ _ _ E E
# 변화가 없지요.
#
# 이번에는 C 를 해봅시다.
#
# 그럼
# C _ _ _ E E
#
# 다음에는 F 를
# C _ F F E E
#
# 마지막으로 O 를 해보면
# C O F F E E 로 게임은 성공으로 끝나게 됩니다.

# %% [markdown]
# ##본격적인 행맨 게임 규칙 설명
#
# - words 리스트에 추가된 단어들을 사용해주세요
#   - words = ["apple", "banana", "orange", "grape", "lemon"]
#
# - 단어의 길이에 맞게 밑줄을 출력해주세요
#   (예)banana의 경우 _ _ _ _ _ _
#
# - 사용자부터 1글자씩 입력을 받되,
#    - 단어에 입력값이 포함되면 "단어를 맞추셨군요. 더 힘내봐요"라고 출력해주세요"
#    - 단어에 입력값이 포함되어 있지 않다면 "틀렸습니다. 남은 시도 횟수 "란 메시지와 함꼐 남은 횟수를 출력해주세요
#
# - 매번 입력을 받을 때마다 현재까지 맞힌 글자들 표시(맞히면 글자는 밑줄 출력)
#     - 예) a 입력 시 : a _ _ _ _
#           p 입력 시 : a p p _ _
#           c 입력 시 : a p p _ _
#
# - 모든 단어를 맞췄을 경우 "축하합니다! 단어를 맞추셨습니다"와 시도 횟수를 출력해주세요
#
#
# 행맨은 정말 유명 게임으로 찾아볼 수 있는 자료들이 많습니다.
# 문제가 어려우신 경우 구글링 통해 문제를 해결해보세요.

# %%
# 기본 라이브러리라 파이썬 설치시 자동으로 설치됩니다!
# random 모듈은 랜덤한 숫자를 생성할 때 사용합니다.
import random

# 게임에 사용될 단어 목록
words = ["apple", "banana", "orange", "grape", "lemon"]

# 행맨 그림
hangman_pics = [
    """
     ------
     |    |
     |
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |    |
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\\
     |
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\\
     |   /
     |
    ---""",
    """
     ------
     |    |
     |    O
     |   /|\\
     |   / \\
     |
    ---""",
]

import time
class HangmanGame:
    def __init__(self):
        self.words = ["apple", "banana", "orange", "grape", "lemon"]
        self.rand_words = random.choice(self.words) #랜덤으로 문자를 가져옴
        self.guessed = ['_']*len(self.rand_words) #랜덤으로 가져온 문자열 개수와 _를 곱한 리스트

    def display(self):
        pass

    def play(self):
        print('게임을 시작합니다.')
        print(f'단어 : {' '.join(self.guessed)}')
        chance = 0 #실패 횟수
        num_chance = len(list(self.rand_words)) #성공 횟수
        try_num = 0 #전체 횟수

        while "_" in self.guessed: #guessed의 문자열에 _가 있으면 True 없으면 False
            guess = input('알파벳을 입력하세요!:') #사용자 입력값

            if guess in self.rand_words: # guess가 랜덤으로 부여된 문자열에 존재하면 True로 진행

                for  num, j in enumerate(self.rand_words): #랜덤 문자열의 인덱스와 값이 존재하면 True로 진행
                    if j == guess: #랜덤문자 와 guess(사용자 입력값)가 같으면 True로 진행
                        self.guessed[num] = guess #guessed(_로 이루어진 리스트)의 인덱스을 guess(사용자 입력값으로 바꿈)

                print(f'단어 : {" ".join(self.guessed)}') #맞춘 단어를 확인 가능 하도록 init의 바뀐 guessed를 공백문자로 합하여 출력
                if "_" in self.guessed: #_가 아직 guessed에 있다면 
                    print('단어를 맞추셨군요. 더 힘내봐요')
                    num_chance -= 1
                    try_num += 1

                else: #guessed에 _가 없다면 print문을 출력하고 while문 break
                    print(f'축하합니다! 단어를 맞추셨습니다. {try_num}회 시도 하였습니다!')
                    break


            else: # guess가 랜덤 부여 문자열에 없다면 실패 횟수와 전체 횟수를 증가 시키고 실패 횟수가 7회일 시 "Game over"출력 및 while문 break
                print(hangman_pics[chance])
                print('틀렸습니다.')
                chance += 1
                try_num +=1
                if chance == 7:
                    print('Game over')
                    break



if __name__ == "__main__":
    game = HangmanGame()
    game.play()
# Out:
# 게임을 시작합니다.
# 단어 : _ _ _ _ _
# 단어 : _ _ a _ _
# 단어를 맞추셨군요. 더 힘내봐요
#
#      ------
#      |    |
#      |
#      |
#      |
#      |
#     ---
# 틀렸습니다.
# 단어 : g _ a _ _
# 단어를 맞추셨군요. 더 힘내봐요
# 단어 : g r a _ _
# 단어를 맞추셨군요. 더 힘내봐요
#
#      ------
#      |    |
#      |    O
#      |
#      |
#      |
#     ---
# 틀렸습니다.
# 단어 : g r a p _
# 단어를 맞추셨군요. 더 힘내봐요
# 단어 : g r a p e
# 축하합니다! 단어를 맞추셨습니다. 6회 시도 하였습니다!
